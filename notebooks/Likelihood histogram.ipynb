# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# Fixing random state for reproducibility
fig, ax = plt.subplots(figsize=(20, 10))

# Example data
methods = ['Fixed variance', 'Single vM', 'Mixture (5 samples)', 'Mixture (10 samples)', 'Mixture (50 samples)']
x_pos = np.arange(len(methods))
performance = np.asarray([1.05, 0.88, 0.64,  0.51,  0.49])
error = [0.031, 0.043, 0.035, 0.035, 0.035]

#ax.axis('off')
ax.bar(x_pos, performance, yerr=error, align='center', color=['gray', 'green','purple', 'orange', 'blue'],  ecolor='black')
ax.set_xticks(x_pos)
ax.set_xticklabels(methods)
#, color=['gray', 'green','purple']
#ax.set_yticks(range(0, 10))
#ax.set_ylabel('mean absolute angular deviation')
#ax.set_yticklabels([str(tick)+"$^{\circ}$"  for tick in range(0, 10)])

#ax.set_title('Log-likelihood\n (higher is better)')

for spine in plt.gca().spines.values():
    spine.set_visible(False)

plt.show()
#plt.savefig("Pascal_likelihood.png", dpi=300)
