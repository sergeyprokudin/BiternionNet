# %%
from utils.caviar import load_caviar

# %%
(xtr, ytr_deg), (xval, yval_deg), (xte, yte_deg) = load_caviar('data//CAVIAR-o.pkl.gz')

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
plt.imshow(xtr[1207])
